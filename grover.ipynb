# %%
from qiskit_ibm_runtime import QiskitRuntimeService
 
service = QiskitRuntimeService(channel="ibm_quantum", token="3d1a8b0562aeba7fafdca151c4b400f50edfc45b3e3c6786a75ef351bc9e7e62636173c3d6563250babfccdc29da77155655b46d4d39a4e3d49297928c156f93")

# %%
from qiskit import QuantumRegister, ClassicalRegister, QuantumCircuit
from qiskit_aer import Aer
from qiskit.visualization import plot_histogram
import matplotlib.pyplot as plt
from qiskit.compiler import transpile
import math
from qiskit.circuit.library import C3XGate


def procesar_y_simular(m):
    simulator = Aer.get_backend('qasm_simulator') 
    qreg_q = QuantumRegister(5, 'q')
    creg_c = ClassicalRegister(3, 'c')
    circuit = QuantumCircuit(qreg_q, creg_c)

    circuit.h(qreg_q[0])
    circuit.h(qreg_q[1])
    circuit.h(qreg_q[2])
    circuit.barrier(qreg_q[0], qreg_q[1], qreg_q[2], qreg_q[3])
    circuit.x(qreg_q[3])
    circuit.h(qreg_q[3])
    circuit.barrier(qreg_q[0], qreg_q[1], qreg_q[2], qreg_q[3])
    circuit.x(qreg_q[0])
    circuit.x(qreg_q[1])
    circuit.x(qreg_q[2])
    circuit.append(C3XGate(), [qreg_q[2], qreg_q[0], qreg_q[1], qreg_q[3]])
    circuit.x(qreg_q[0])
    circuit.x(qreg_q[1])
    circuit.x(qreg_q[2])
    circuit.barrier(qreg_q[0], qreg_q[1], qreg_q[2], qreg_q[3])
    circuit.x(qreg_q[0])
    circuit.append(C3XGate(), [qreg_q[2], qreg_q[0], qreg_q[1], qreg_q[3]])
    circuit.x(qreg_q[0])
    circuit.barrier(qreg_q[0], qreg_q[1], qreg_q[2], qreg_q[3])
    circuit.x(qreg_q[1])
    circuit.x(qreg_q[2])
    circuit.append(C3XGate(), [qreg_q[2], qreg_q[0], qreg_q[1], qreg_q[3]])
    circuit.x(qreg_q[1])
    circuit.x(qreg_q[2])
    circuit.barrier(qreg_q[0], qreg_q[1], qreg_q[2], qreg_q[3])
    circuit.x(qreg_q[2])
    circuit.append(C3XGate(), [qreg_q[2], qreg_q[0], qreg_q[1], qreg_q[3]])
    circuit.x(qreg_q[2])
    circuit.barrier(qreg_q[0], qreg_q[1], qreg_q[2], qreg_q[3])
    circuit.append(C3XGate(), [qreg_q[2], qreg_q[0], qreg_q[1], qreg_q[3]])
    circuit.barrier(qreg_q[0], qreg_q[1], qreg_q[2], qreg_q[3])
    circuit.h(qreg_q[0])
    circuit.h(qreg_q[1])
    circuit.h(qreg_q[2])
    circuit.barrier(qreg_q[0], qreg_q[1], qreg_q[2], qreg_q[3])
    circuit.x(qreg_q[0])
    circuit.x(qreg_q[1])
    circuit.append(C3XGate(), [qreg_q[2], qreg_q[0], qreg_q[1], qreg_q[3]])
    circuit.x(qreg_q[0])
    circuit.x(qreg_q[1])
    circuit.barrier(qreg_q[0], qreg_q[1], qreg_q[2], qreg_q[3])
    circuit.x(qreg_q[0])
    circuit.x(qreg_q[2])
    circuit.append(C3XGate(), [qreg_q[2], qreg_q[0], qreg_q[1], qreg_q[3]])
    circuit.x(qreg_q[0])
    circuit.x(qreg_q[2])
    circuit.barrier(qreg_q[0], qreg_q[1], qreg_q[2], qreg_q[3])
    circuit.x(qreg_q[0])
    circuit.append(C3XGate(), [qreg_q[2], qreg_q[0], qreg_q[1], qreg_q[3]])
    circuit.x(qreg_q[0])
    circuit.barrier(qreg_q[0], qreg_q[1], qreg_q[2], qreg_q[3])
    circuit.x(qreg_q[1])
    circuit.x(qreg_q[2])
    circuit.append(C3XGate(), [qreg_q[2], qreg_q[0], qreg_q[1], qreg_q[3]])
    circuit.x(qreg_q[1])
    circuit.x(qreg_q[2])
    circuit.barrier(qreg_q[0], qreg_q[1], qreg_q[2], qreg_q[3])
    circuit.x(qreg_q[1])
    circuit.append(C3XGate(), [qreg_q[2], qreg_q[0], qreg_q[1], qreg_q[3]])
    circuit.x(qreg_q[1])
    circuit.barrier(qreg_q[0], qreg_q[1], qreg_q[2], qreg_q[3])
    circuit.x(qreg_q[2])
    circuit.append(C3XGate(), [qreg_q[2], qreg_q[0], qreg_q[1], qreg_q[3]])
    circuit.x(qreg_q[2])
    circuit.barrier(qreg_q[0], qreg_q[1], qreg_q[2], qreg_q[3])
    circuit.append(C3XGate(), [qreg_q[2], qreg_q[0], qreg_q[1], qreg_q[3]])
    circuit.barrier(qreg_q[0], qreg_q[1], qreg_q[2], qreg_q[3])
    circuit.h(qreg_q[0])
    circuit.h(qreg_q[1])
    circuit.h(qreg_q[2])
    circuit.barrier(qreg_q[0], qreg_q[1], qreg_q[2], qreg_q[3], qreg_q[4])
    circuit.x(qreg_q[4])
    circuit.h(qreg_q[4])
    circuit.barrier(qreg_q[0], qreg_q[1], qreg_q[2], qreg_q[3], qreg_q[4])
    circuit.x(qreg_q[0])
    circuit.x(qreg_q[1])
    circuit.x(qreg_q[2])
    circuit.append(C3XGate(), [qreg_q[0], qreg_q[2], qreg_q[1], qreg_q[4]])
    circuit.x(qreg_q[0])
    circuit.x(qreg_q[1])
    circuit.x(qreg_q[2])
    circuit.barrier(qreg_q[0], qreg_q[1], qreg_q[2], qreg_q[3])
    circuit.x(qreg_q[0])
    circuit.append(C3XGate(), [qreg_q[0], qreg_q[2], qreg_q[1], qreg_q[4]])
    circuit.x(qreg_q[0])
    circuit.barrier(qreg_q[0], qreg_q[1], qreg_q[2], qreg_q[3])
    circuit.x(qreg_q[1])
    circuit.x(qreg_q[2])
    circuit.append(C3XGate(), [qreg_q[0], qreg_q[2], qreg_q[1], qreg_q[4]])
    circuit.x(qreg_q[1])
    circuit.x(qreg_q[2])
    circuit.barrier(qreg_q[0], qreg_q[1], qreg_q[2], qreg_q[3])
    circuit.x(qreg_q[2])
    circuit.append(C3XGate(), [qreg_q[0], qreg_q[2], qreg_q[1], qreg_q[4]])
    circuit.x(qreg_q[2])
    circuit.barrier(qreg_q[0], qreg_q[1], qreg_q[2], qreg_q[3])
    circuit.append(C3XGate(), [qreg_q[0], qreg_q[2], qreg_q[1], qreg_q[4]])
    circuit.barrier(qreg_q[0], qreg_q[1], qreg_q[2], qreg_q[3])
    circuit.h(qreg_q[0])
    circuit.h(qreg_q[1])
    circuit.h(qreg_q[2])
    circuit.barrier(qreg_q[0], qreg_q[1], qreg_q[2], qreg_q[3])
    circuit.x(qreg_q[0])
    circuit.x(qreg_q[1])
    circuit.append(C3XGate(), [qreg_q[0], qreg_q[2], qreg_q[1], qreg_q[4]])
    circuit.x(qreg_q[0])
    circuit.x(qreg_q[1])
    circuit.barrier(qreg_q[0], qreg_q[1], qreg_q[2], qreg_q[3])
    circuit.x(qreg_q[0])
    circuit.x(qreg_q[2])
    circuit.append(C3XGate(), [qreg_q[0], qreg_q[2], qreg_q[1], qreg_q[4]])
    circuit.x(qreg_q[0])
    circuit.x(qreg_q[2])
    circuit.barrier(qreg_q[0], qreg_q[1], qreg_q[2], qreg_q[3])
    circuit.x(qreg_q[0])
    circuit.append(C3XGate(), [qreg_q[0], qreg_q[2], qreg_q[1], qreg_q[4]])
    circuit.x(qreg_q[0])
    circuit.barrier(qreg_q[0], qreg_q[1], qreg_q[2], qreg_q[3])
    circuit.x(qreg_q[1])
    circuit.x(qreg_q[2])
    circuit.append(C3XGate(), [qreg_q[0], qreg_q[2], qreg_q[1], qreg_q[4]])
    circuit.x(qreg_q[1])
    circuit.x(qreg_q[2])
    circuit.barrier(qreg_q[0], qreg_q[1], qreg_q[2], qreg_q[3])
    circuit.x(qreg_q[1])
    circuit.append(C3XGate(), [qreg_q[0], qreg_q[2], qreg_q[1], qreg_q[4]])
    circuit.x(qreg_q[1])
    circuit.barrier(qreg_q[0], qreg_q[1], qreg_q[2], qreg_q[3])
    circuit.x(qreg_q[2])
    circuit.append(C3XGate(), [qreg_q[0], qreg_q[2], qreg_q[1], qreg_q[4]])
    circuit.x(qreg_q[2])
    circuit.barrier(qreg_q[0], qreg_q[1], qreg_q[2], qreg_q[3])
    circuit.append(C3XGate(), [qreg_q[0], qreg_q[2], qreg_q[1], qreg_q[4]])
    circuit.barrier(qreg_q[0], qreg_q[1], qreg_q[2], qreg_q[3])
    circuit.h(qreg_q[0])
    circuit.h(qreg_q[1])
    circuit.h(qreg_q[2])
    circuit.barrier(qreg_q[0], qreg_q[1], qreg_q[2], qreg_q[3])
    circuit.measure(qreg_q[0], creg_c[2])
    circuit.measure(qreg_q[1], creg_c[1])
    circuit.measure(qreg_q[2], creg_c[0])
    print(circuit)
    
    compiled_circuit = transpile(circuit, simulator)
    job = simulator.run(compiled_circuit, shots=1000)
    result = job.result()
    counts = result.get_counts(circuit)
    plt.title("EJEMPLO 1")
    labels = list(counts.keys())
    values = list(counts.values())
    for i in range (len(values)):
        values[i] = values[i]/10
    plt.bar(labels, values, color='skyblue')
    plt.xticks(rotation=45)
    plt.show()


procesar_y_simular(3)

# %%
from qiskit import QuantumRegister, ClassicalRegister, QuantumCircuit
from qiskit_aer import Aer
from qiskit.visualization import plot_histogram
import matplotlib.pyplot as plt
from qiskit.compiler import transpile
import math
from qiskit.circuit.library import C3XGate


def procesar_y_simular(m):
    simulator = Aer.get_backend('qasm_simulator') 
    qreg_q = QuantumRegister(5, 'q')
    greg_c = ClassicalRegister(3, 'c')
    circuit = QuantumCircuit(qreg_q,greg_c)

    circuit.h(qreg_q[0])
    circuit.h(qreg_q[1])
    circuit.h(qreg_q[2])
    circuit.barrier(qreg_q[0], qreg_q[1], qreg_q[2], qreg_q[3])
    circuit.x(qreg_q[3])
    circuit.h(qreg_q[3])
    circuit.barrier(qreg_q[0], qreg_q[1], qreg_q[2], qreg_q[3])
    circuit.x(qreg_q[0])
    circuit.x(qreg_q[1])
    circuit.x(qreg_q[2])
    circuit.append(C3XGate(), [qreg_q[2], qreg_q[0], qreg_q[1], qreg_q[3]])
    circuit.x(qreg_q[0])
    circuit.x(qreg_q[1])
    circuit.x(qreg_q[2])
    circuit.barrier(qreg_q[0], qreg_q[1], qreg_q[2], qreg_q[3])
    circuit.x(qreg_q[0])
    circuit.append(C3XGate(), [qreg_q[2], qreg_q[0], qreg_q[1], qreg_q[3]])
    circuit.x(qreg_q[0])
    circuit.barrier(qreg_q[0], qreg_q[1], qreg_q[2], qreg_q[3])
    circuit.x(qreg_q[1])
    circuit.x(qreg_q[2])
    circuit.append(C3XGate(), [qreg_q[2], qreg_q[0], qreg_q[1], qreg_q[3]])
    circuit.x(qreg_q[1])
    circuit.x(qreg_q[2])
    circuit.barrier(qreg_q[0], qreg_q[1], qreg_q[2], qreg_q[3])
    circuit.x(qreg_q[1])
    circuit.append(C3XGate(), [qreg_q[2], qreg_q[0], qreg_q[1], qreg_q[3]])
    circuit.x(qreg_q[1])
    circuit.barrier(qreg_q[0], qreg_q[1], qreg_q[2], qreg_q[3])
    circuit.append(C3XGate(), [qreg_q[2], qreg_q[0], qreg_q[1], qreg_q[3]])
    circuit.barrier(qreg_q[0], qreg_q[1], qreg_q[2], qreg_q[3])
    circuit.h(qreg_q[0])
    circuit.h(qreg_q[1])
    circuit.h(qreg_q[2])
    circuit.barrier(qreg_q[0], qreg_q[1], qreg_q[2], qreg_q[3])
    circuit.x(qreg_q[0])
    circuit.x(qreg_q[1])
    circuit.append(C3XGate(), [qreg_q[2], qreg_q[0], qreg_q[1], qreg_q[3]])
    circuit.x(qreg_q[0])
    circuit.x(qreg_q[1])
    circuit.barrier(qreg_q[0], qreg_q[1], qreg_q[2], qreg_q[3])
    circuit.x(qreg_q[0])
    circuit.x(qreg_q[2])
    circuit.append(C3XGate(), [qreg_q[2], qreg_q[0], qreg_q[1], qreg_q[3]])
    circuit.x(qreg_q[0])
    circuit.x(qreg_q[2])
    circuit.barrier(qreg_q[0], qreg_q[1], qreg_q[2], qreg_q[3])
    circuit.x(qreg_q[0])
    circuit.append(C3XGate(), [qreg_q[2], qreg_q[0], qreg_q[1], qreg_q[3]])
    circuit.x(qreg_q[0])
    circuit.barrier(qreg_q[0], qreg_q[1], qreg_q[2], qreg_q[3])
    circuit.x(qreg_q[1])
    circuit.x(qreg_q[2])
    circuit.append(C3XGate(), [qreg_q[2], qreg_q[0], qreg_q[1], qreg_q[3]])
    circuit.x(qreg_q[1])
    circuit.x(qreg_q[2])
    circuit.barrier(qreg_q[0], qreg_q[1], qreg_q[2], qreg_q[3])
    circuit.x(qreg_q[1])
    circuit.append(C3XGate(), [qreg_q[2], qreg_q[0], qreg_q[1], qreg_q[3]])
    circuit.x(qreg_q[1])
    circuit.barrier(qreg_q[0], qreg_q[1], qreg_q[2], qreg_q[3])
    circuit.x(qreg_q[2])
    circuit.append(C3XGate(), [qreg_q[2], qreg_q[0], qreg_q[1], qreg_q[3]])
    circuit.x(qreg_q[2])
    circuit.barrier(qreg_q[0], qreg_q[1], qreg_q[2], qreg_q[3])
    circuit.append(C3XGate(), [qreg_q[2], qreg_q[0], qreg_q[1], qreg_q[3]])
    circuit.barrier(qreg_q[0], qreg_q[1], qreg_q[2], qreg_q[3])
    circuit.h(qreg_q[0])
    circuit.h(qreg_q[1])
    circuit.h(qreg_q[2])
    circuit.barrier(qreg_q[0], qreg_q[1], qreg_q[2], qreg_q[3], qreg_q[4])
    circuit.x(qreg_q[4])
    circuit.h(qreg_q[4])
    circuit.barrier(qreg_q[0], qreg_q[1], qreg_q[2], qreg_q[3], qreg_q[4])
    circuit.x(qreg_q[0])
    circuit.x(qreg_q[1])
    circuit.x(qreg_q[2])
    circuit.append(C3XGate(), [qreg_q[0], qreg_q[2], qreg_q[1], qreg_q[4]])
    circuit.x(qreg_q[0])
    circuit.x(qreg_q[1])
    circuit.x(qreg_q[2])
    circuit.barrier(qreg_q[0], qreg_q[1], qreg_q[2], qreg_q[3])
    circuit.x(qreg_q[0])
    circuit.append(C3XGate(), [qreg_q[0], qreg_q[2], qreg_q[1], qreg_q[4]])
    circuit.x(qreg_q[0])
    circuit.barrier(qreg_q[0], qreg_q[1], qreg_q[2], qreg_q[3])
    circuit.x(qreg_q[1])
    circuit.x(qreg_q[2])
    circuit.append(C3XGate(), [qreg_q[0], qreg_q[2], qreg_q[1], qreg_q[4]])
    circuit.x(qreg_q[1])
    circuit.x(qreg_q[2])
    circuit.barrier(qreg_q[0], qreg_q[1], qreg_q[2], qreg_q[3])
    circuit.x(qreg_q[1])
    circuit.append(C3XGate(), [qreg_q[0], qreg_q[2], qreg_q[1], qreg_q[4]])
    circuit.x(qreg_q[1])
    circuit.barrier(qreg_q[0], qreg_q[1], qreg_q[2], qreg_q[3])
    circuit.append(C3XGate(), [qreg_q[0], qreg_q[2], qreg_q[1], qreg_q[4]])
    circuit.barrier(qreg_q[0], qreg_q[1], qreg_q[2], qreg_q[3])
    circuit.h(qreg_q[0])
    circuit.h(qreg_q[1])
    circuit.h(qreg_q[2])
    circuit.barrier(qreg_q[0], qreg_q[1], qreg_q[2], qreg_q[3])
    circuit.x(qreg_q[0])
    circuit.x(qreg_q[1])
    circuit.append(C3XGate(), [qreg_q[0], qreg_q[2], qreg_q[1], qreg_q[4]])
    circuit.x(qreg_q[0])
    circuit.x(qreg_q[1])
    circuit.barrier(qreg_q[0], qreg_q[1], qreg_q[2], qreg_q[3])
    circuit.x(qreg_q[0])
    circuit.x(qreg_q[2])
    circuit.append(C3XGate(), [qreg_q[0], qreg_q[2], qreg_q[1], qreg_q[4]])
    circuit.x(qreg_q[0])
    circuit.x(qreg_q[2])
    circuit.barrier(qreg_q[0], qreg_q[1], qreg_q[2], qreg_q[3])
    circuit.x(qreg_q[0])
    circuit.append(C3XGate(), [qreg_q[0], qreg_q[2], qreg_q[1], qreg_q[4]])
    circuit.x(qreg_q[0])
    circuit.barrier(qreg_q[0], qreg_q[1], qreg_q[2], qreg_q[3])
    circuit.x(qreg_q[1])
    circuit.x(qreg_q[2])
    circuit.append(C3XGate(), [qreg_q[0], qreg_q[2], qreg_q[1], qreg_q[4]])
    circuit.x(qreg_q[1])
    circuit.x(qreg_q[2])
    circuit.barrier(qreg_q[0], qreg_q[1], qreg_q[2], qreg_q[3])
    circuit.x(qreg_q[1])
    circuit.append(C3XGate(), [qreg_q[0], qreg_q[2], qreg_q[1], qreg_q[4]])
    circuit.x(qreg_q[1])
    circuit.barrier(qreg_q[0], qreg_q[1], qreg_q[2], qreg_q[3])
    circuit.x(qreg_q[2])
    circuit.append(C3XGate(), [qreg_q[0], qreg_q[2], qreg_q[1], qreg_q[4]])
    circuit.x(qreg_q[2])
    circuit.barrier(qreg_q[0], qreg_q[1], qreg_q[2], qreg_q[3])
    circuit.append(C3XGate(), [qreg_q[0], qreg_q[2], qreg_q[1], qreg_q[4]])
    circuit.barrier(qreg_q[0], qreg_q[1], qreg_q[2], qreg_q[3])
    circuit.h(qreg_q[0])
    circuit.h(qreg_q[1])
    circuit.h(qreg_q[2])
    circuit.barrier(qreg_q[0], qreg_q[1], qreg_q[2], qreg_q[3])
    circuit.measure(qreg_q[0], greg_c[2])
    circuit.measure(qreg_q[1], greg_c[1])
    circuit.measure(qreg_q[2], greg_c[0])
    print(circuit)
    
    compiled_circuit = transpile(circuit, simulator)
    job = simulator.run(compiled_circuit, shots=1000)
    result = job.result()
    counts = result.get_counts(circuit)
    plt.title("EJEMPLO 2")
    labels = list(counts.keys())
    values = list(counts.values())
    for i in range (len(values)):
        values[i] = values[i]/10
    plt.bar(labels, values, color='skyblue')
    plt.xticks(rotation=45)
    plt.show()


procesar_y_simular(3)
# Out:
#      ┌───┐ ░            ░ ┌───┐     ┌───┐ ░ ┌───┐     ┌───┐ ░                »
# q_0: ┤ H ├─░────────────░─┤ X ├──■──┤ X ├─░─┤ X ├──■──┤ X ├─░────────■───────»
#      ├───┤ ░            ░ ├───┤  │  ├───┤ ░ └───┘  │  └───┘ ░ ┌───┐  │  ┌───┐»
# q_1: ┤ H ├─░────────────░─┤ X ├──■──┤ X ├─░────────■────────░─┤ X ├──■──┤ X ├»
#      ├───┤ ░            ░ ├───┤  │  ├───┤ ░        │        ░ ├───┤  │  ├───┤»
# q_2: ┤ H ├─░────────────░─┤ X ├──■──┤ X ├─░────────■────────░─┤ X ├──■──┤ X ├»
#      └───┘ ░ ┌───┐┌───┐ ░ └───┘┌─┴─┐└───┘ ░      ┌─┴─┐      ░ └───┘┌─┴─┐└───┘»
# q_3: ──────░─┤ X ├┤ H ├─░──────┤ X ├──────░──────┤ X ├──────░──────┤ X ├─────»
#            ░ └───┘└───┘ ░      └───┘      ░      └───┘      ░      └───┘     »
# q_4: ────────────────────────────────────────────────────────────────────────»
#                                                                              »
# c: 3/════════════════════════════════════════════════════════════════════════»
# ...

# %%
from qiskit import QuantumRegister, ClassicalRegister, QuantumCircuit
from qiskit_aer import Aer
from qiskit.visualization import plot_histogram
import matplotlib.pyplot as plt
from qiskit.compiler import transpile
import math
from qiskit.circuit.library import C3XGate


def procesar_y_simular(m):
    simulator = Aer.get_backend('qasm_simulator') 
    qreg_q = QuantumRegister(5, 'q')
    creg_c = ClassicalRegister(3, 'c')
    circuit = QuantumCircuit(qreg_q, creg_c)

    circuit.h(qreg_q[0])
    circuit.h(qreg_q[1])
    circuit.h(qreg_q[2])
    circuit.barrier(qreg_q[0], qreg_q[1], qreg_q[2], qreg_q[3])
    circuit.x(qreg_q[3])
    circuit.h(qreg_q[3])
    circuit.barrier(qreg_q[0], qreg_q[1], qreg_q[2], qreg_q[3])
    circuit.x(qreg_q[0])
    circuit.x(qreg_q[1])
    circuit.x(qreg_q[2])
    circuit.append(C3XGate(), [qreg_q[2], qreg_q[0], qreg_q[1], qreg_q[3]])
    circuit.x(qreg_q[0])
    circuit.x(qreg_q[1])
    circuit.x(qreg_q[2])
    circuit.barrier(qreg_q[0], qreg_q[1], qreg_q[2], qreg_q[3])
    circuit.x(qreg_q[0])
    circuit.append(C3XGate(), [qreg_q[2], qreg_q[0], qreg_q[1], qreg_q[3]])
    circuit.x(qreg_q[0])
    circuit.barrier(qreg_q[0], qreg_q[1], qreg_q[2], qreg_q[3])
    circuit.x(qreg_q[1])
    circuit.append(C3XGate(), [qreg_q[2], qreg_q[0], qreg_q[1], qreg_q[3]])
    circuit.x(qreg_q[1])
    circuit.barrier(qreg_q[0], qreg_q[1], qreg_q[2], qreg_q[3])
    circuit.x(qreg_q[2])
    circuit.append(C3XGate(), [qreg_q[2], qreg_q[0], qreg_q[1], qreg_q[3]])
    circuit.x(qreg_q[2])
    circuit.barrier(qreg_q[0], qreg_q[1], qreg_q[2], qreg_q[3])
    circuit.append(C3XGate(), [qreg_q[2], qreg_q[0], qreg_q[1], qreg_q[3]])
    circuit.barrier(qreg_q[0], qreg_q[1], qreg_q[2], qreg_q[3])
    circuit.h(qreg_q[0])
    circuit.h(qreg_q[1])
    circuit.h(qreg_q[2])
    circuit.barrier(qreg_q[0], qreg_q[1], qreg_q[2], qreg_q[3])
    circuit.x(qreg_q[0])
    circuit.x(qreg_q[1])
    circuit.append(C3XGate(), [qreg_q[2], qreg_q[0], qreg_q[1], qreg_q[3]])
    circuit.x(qreg_q[0])
    circuit.x(qreg_q[1])
    circuit.barrier(qreg_q[0], qreg_q[1], qreg_q[2], qreg_q[3])
    circuit.x(qreg_q[0])
    circuit.x(qreg_q[2])
    circuit.append(C3XGate(), [qreg_q[2], qreg_q[0], qreg_q[1], qreg_q[3]])
    circuit.x(qreg_q[0])
    circuit.x(qreg_q[2])
    circuit.barrier(qreg_q[0], qreg_q[1], qreg_q[2], qreg_q[3])
    circuit.x(qreg_q[0])
    circuit.append(C3XGate(), [qreg_q[2], qreg_q[0], qreg_q[1], qreg_q[3]])
    circuit.x(qreg_q[0])
    circuit.barrier(qreg_q[0], qreg_q[1], qreg_q[2], qreg_q[3])
    circuit.x(qreg_q[1])
    circuit.x(qreg_q[2])
    circuit.append(C3XGate(), [qreg_q[2], qreg_q[0], qreg_q[1], qreg_q[3]])
    circuit.x(qreg_q[1])
    circuit.x(qreg_q[2])
    circuit.barrier(qreg_q[0], qreg_q[1], qreg_q[2], qreg_q[3])
    circuit.x(qreg_q[1])
    circuit.append(C3XGate(), [qreg_q[2], qreg_q[0], qreg_q[1], qreg_q[3]])
    circuit.x(qreg_q[1])
    circuit.barrier(qreg_q[0], qreg_q[1], qreg_q[2], qreg_q[3])
    circuit.x(qreg_q[2])
    circuit.append(C3XGate(), [qreg_q[2], qreg_q[0], qreg_q[1], qreg_q[3]])
    circuit.x(qreg_q[2])
    circuit.barrier(qreg_q[0], qreg_q[1], qreg_q[2], qreg_q[3])
    circuit.append(C3XGate(), [qreg_q[2], qreg_q[0], qreg_q[1], qreg_q[3]])
    circuit.barrier(qreg_q[0], qreg_q[1], qreg_q[2], qreg_q[3])
    circuit.h(qreg_q[0])
    circuit.h(qreg_q[1])
    circuit.h(qreg_q[2])
    circuit.barrier(qreg_q[0], qreg_q[1], qreg_q[2], qreg_q[3], qreg_q[4])
    circuit.x(qreg_q[4])
    circuit.h(qreg_q[4])
    circuit.barrier(qreg_q[0], qreg_q[1], qreg_q[2], qreg_q[3], qreg_q[4])
    circuit.x(qreg_q[0])
    circuit.x(qreg_q[1])
    circuit.x(qreg_q[2])
    circuit.append(C3XGate(), [qreg_q[0], qreg_q[2], qreg_q[1], qreg_q[4]])
    circuit.x(qreg_q[0])
    circuit.x(qreg_q[1])
    circuit.x(qreg_q[2])
    circuit.barrier(qreg_q[0], qreg_q[1], qreg_q[2], qreg_q[3])
    circuit.x(qreg_q[0])
    circuit.append(C3XGate(), [qreg_q[0], qreg_q[2], qreg_q[1], qreg_q[4]])
    circuit.x(qreg_q[0])
    circuit.barrier(qreg_q[0], qreg_q[1], qreg_q[2], qreg_q[3])
    circuit.x(qreg_q[1])
    circuit.append(C3XGate(), [qreg_q[0], qreg_q[2], qreg_q[1], qreg_q[4]])
    circuit.x(qreg_q[1])
    circuit.barrier(qreg_q[0], qreg_q[1], qreg_q[2], qreg_q[3])
    circuit.x(qreg_q[2])
    circuit.append(C3XGate(), [qreg_q[0], qreg_q[2], qreg_q[1], qreg_q[4]])
    circuit.x(qreg_q[2])
    circuit.barrier(qreg_q[0], qreg_q[1], qreg_q[2], qreg_q[3])
    circuit.append(C3XGate(), [qreg_q[0], qreg_q[2], qreg_q[1], qreg_q[4]])
    circuit.barrier(qreg_q[0], qreg_q[1], qreg_q[2], qreg_q[3])
    circuit.h(qreg_q[0])
    circuit.h(qreg_q[1])
    circuit.h(qreg_q[2])
    circuit.barrier(qreg_q[0], qreg_q[1], qreg_q[2], qreg_q[3])
    circuit.x(qreg_q[0])
    circuit.x(qreg_q[1])
    circuit.append(C3XGate(), [qreg_q[0], qreg_q[2], qreg_q[1], qreg_q[4]])
    circuit.x(qreg_q[0])
    circuit.x(qreg_q[1])
    circuit.barrier(qreg_q[0], qreg_q[1], qreg_q[2], qreg_q[3])
    circuit.x(qreg_q[0])
    circuit.x(qreg_q[2])
    circuit.append(C3XGate(), [qreg_q[0], qreg_q[2], qreg_q[1], qreg_q[4]])
    circuit.x(qreg_q[0])
    circuit.x(qreg_q[2])
    circuit.barrier(qreg_q[0], qreg_q[1], qreg_q[2], qreg_q[3])
    circuit.x(qreg_q[0])
    circuit.append(C3XGate(), [qreg_q[0], qreg_q[2], qreg_q[1], qreg_q[4]])
    circuit.x(qreg_q[0])
    circuit.barrier(qreg_q[0], qreg_q[1], qreg_q[2], qreg_q[3])
    circuit.x(qreg_q[1])
    circuit.x(qreg_q[2])
    circuit.append(C3XGate(), [qreg_q[0], qreg_q[2], qreg_q[1], qreg_q[4]])
    circuit.x(qreg_q[1])
    circuit.x(qreg_q[2])
    circuit.barrier(qreg_q[0], qreg_q[1], qreg_q[2], qreg_q[3])
    circuit.x(qreg_q[1])
    circuit.append(C3XGate(), [qreg_q[0], qreg_q[2], qreg_q[1], qreg_q[4]])
    circuit.x(qreg_q[1])
    circuit.barrier(qreg_q[0], qreg_q[1], qreg_q[2], qreg_q[3])
    circuit.x(qreg_q[2])
    circuit.append(C3XGate(), [qreg_q[0], qreg_q[2], qreg_q[1], qreg_q[4]])
    circuit.x(qreg_q[2])
    circuit.barrier(qreg_q[0], qreg_q[1], qreg_q[2], qreg_q[3])
    circuit.append(C3XGate(), [qreg_q[0], qreg_q[2], qreg_q[1], qreg_q[4]])
    circuit.barrier(qreg_q[0], qreg_q[1], qreg_q[2], qreg_q[3])
    circuit.h(qreg_q[0])
    circuit.h(qreg_q[1])
    circuit.h(qreg_q[2])
    circuit.barrier(qreg_q[0], qreg_q[1], qreg_q[2], qreg_q[3])
    circuit.measure(qreg_q[0], creg_c[2])
    circuit.measure(qreg_q[1], creg_c[1])
    circuit.measure(qreg_q[2], creg_c[0])
    print(circuit)
        
    compiled_circuit = transpile(circuit, simulator)
    job = simulator.run(compiled_circuit, shots=100000000)
    result = job.result()
    counts = result.get_counts(circuit)
    plt.title("EJEMPLO 3")
    labels = list(counts.keys())
    values = list(counts.values())
    
    for i in range (len(values)):
        values[i] = values[i]/10
    plt.bar(labels, values, color='skyblue')
    plt.xticks(rotation=45)
    plt.show()


procesar_y_simular(3)
# Out:
#      ┌───┐ ░            ░ ┌───┐     ┌───┐ ░ ┌───┐     ┌───┐ ░                »
# q_0: ┤ H ├─░────────────░─┤ X ├──■──┤ X ├─░─┤ X ├──■──┤ X ├─░────────■───────»
#      ├───┤ ░            ░ ├───┤  │  ├───┤ ░ └───┘  │  └───┘ ░ ┌───┐  │  ┌───┐»
# q_1: ┤ H ├─░────────────░─┤ X ├──■──┤ X ├─░────────■────────░─┤ X ├──■──┤ X ├»
#      ├───┤ ░            ░ ├───┤  │  ├───┤ ░        │        ░ └───┘  │  └───┘»
# q_2: ┤ H ├─░────────────░─┤ X ├──■──┤ X ├─░────────■────────░────────■───────»
#      └───┘ ░ ┌───┐┌───┐ ░ └───┘┌─┴─┐└───┘ ░      ┌─┴─┐      ░      ┌─┴─┐     »
# q_3: ──────░─┤ X ├┤ H ├─░──────┤ X ├──────░──────┤ X ├──────░──────┤ X ├─────»
#            ░ └───┘└───┘ ░      └───┘      ░      └───┘      ░      └───┘     »
# q_4: ────────────────────────────────────────────────────────────────────────»
#                                                                              »
# c: 3/════════════════════════════════════════════════════════════════════════»
# ...
